# %% [markdown]
# <a href="https://colab.research.google.com/github/KushangShah/AlmaBetter_Assignment/blob/main/Recursion_Fundamentals_Kushang's_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 🎉 Hi there! Welcome to today's assignment on Recursion Fundamentals in Python!
#
# Are you ready to put your skills to the test? Let's dive right in! 💪📚
#
# In this assignment, you will be working with simple recursive functions in Python. Don't worry if you're feeling a bit unsure - you got this! 🤞
#
# Good luck! 🍀🚀

# %% [markdown]
# ## **Activity 1:**

# %% [markdown]
# ### 🧮 **Counting Backwards by 2** 🔢
#
# Design a recursive function to print the numbers in reverse order by decrementing the initial number with a step of 2 until the number is less than or equal to 0.
#
# If the number is zero or negative, print **"Zero!"**, otherwise the function will call itself with the current number decremented by 2 and add "*" equal to the current number to a list.
#
# This will ensure that the numbers are printed in a reverse order and a corresponding number of "*" are also displayed for each iteration.
#
#
# Additionally, find the time and space complexity of the code you have developed.

# %% [markdown]
# ![maxresdefault.jpg](data:image/jpeg;base64,...)

# %%
# Write your code here
def backwords_by_2(n: int):
  if n <=0:
    return 0

  print(n)
  backwords_by_2(n-2)

# %%
i = int(input("Enter the number here: "))
print(f"the backward of {i} is {backwords_by_2(i)}")
# Out:
# Enter the number here: 9999
# 9999
# 9997
# 9995
# 9993
# 9991
# 9989
# 9987
# 9985
# 9983
# 9981
# 9979
# 9977
# 9975
# 9973
# 9971
# 9969
# 9967
# 9965
# 9963
# 9961
# 9959
# 9957
# 9955
# 9953
# 9951
# 9949
# 9947
# 9945
# 9943
# 9941
# 9939
# 9937
# 9935
# 9933
# 9931
# 9929
# 9927
# 9925
# 9923
# 9921
# 9919
# 9917
# 9915
# 9913
# 9911
# 9909
# 9907
# 9905
# 9903
# 9901
# 9899
# 9897
# 9895
# 9893
# 9891
# 9889
# 9887
# 9885
# 9883
# 9881
# 9879
# 9877
# 9875
# 9873
# 9871
# 9869
# 9867
# 9865
# 9863
# 9861
# 9859
# 9857
# 9855
# 9853
# 9851
# 9849
# 9847
# 9845
# 9843
# 9841
# 9839
# 9837
# 9835
# 9833
# 9831
# 9829
# 9827
# 9825
# 9823
# 9821
# 9819
# 9817
# 9815
# 9813
# 9811
# 9809
# 9807
# 9805
# 9803
# 9801
# 9799
# 9797
# 9795
# 9793
# 9791
# 9789
# 9787
# 9785
# 9783
# 9781
# 9779
# 9777
# 9775
# 9773
# 9771
# 9769
# 9767
# 9765
# 9763
# 9761
# 9759
# 9757
# 9755
# 9753
# 9751
# 9749
# 9747
# 9745
# 9743
# 9741
# 9739
# 9737
# 9735
# 9733
# 9731
# 9729
# 9727
# 9725
# ...

# %% [markdown]
# 👉 **Instructions:**
#
# 1. Define a function "backwardsby2" which will print the numbers in reverse order decrementing the initial number by 2.
# 2. If the number is zero or negative then print "Zero!".
# 3. Otherwise do a recursive call with the current number decremented by 2 and also add "*" equal to the current number to a list.
# 4. Print the numbers in a reverse order along with the corresponding numbers of "*" for each iteration.

# %% [markdown]
# ## **Activity 2:**

# %% [markdown]
# ### ❗ **Factorial of a Number** 🔢
#
# Imagine you have been hired as a Python developer for a math education 🏫 startup. You have been assigned a task to develop a program that calculates the factorial of a positive integer using recursion.
#
#
# Additionally, find the time and space complexity of the code you have developed.

# %% [markdown]
# ![factorial.png](data:image/png;base64,...)

# %%
# Write your code here
def factorial(n):
  if n < 0:
    return "invalid number"
  elif n == 0:
    return 1
  else:
    return n * factorial(n-1)

# %%
i = int(input("Enter the number here to get the factorial: "))
print(f"The factorial of {i} is {factorial(i)}")
# Out:
# Enter the number here to get the factorial: 5
# The factorial of 5 is 120

# %% [markdown]
# 👉 **Instructions:**
#
# 1. Ask the user for an input number.
# 2. Define a function called factorial which will make a recursive call.
# 3. If the number is less than zero then print "Factorial doesn't exist for negative numbers".
# 4. If the number is equal to zero then print "Factorial of 0 is 1".
# 5. Otherwise call the function and print the factorial of a positive integer.

# %% [markdown]
# ## **Activity 3:**

# %% [markdown]
# ### **Largest Integer in the List** 🔢
#
# Consider a scenario where you are given a list of integers and you need to find the largest integer in the list using recursion in Python.
#
# Write a Python function called find_largest(lst) that takes a list of integers as input and returns the largest integer in the list using recursion.
#
# For example, given the list `[3, 7, 1, 9, 4, 5]`, the find_largest function should return 9.
#
#
# Additionally, find the time and space complexity of the code you have developed.

# %% [markdown]
# ![largest-element-of-array-in-python.png](data:image/png;base64,...)

# %%
# Write your code here
def find_largest(lst):
    if len(lst) == 1:
        return lst[0]
    else:
        return max(lst[0], find_largest(lst[1:]))

# %%
num = [3, 7, 1, 9, 4, 5]
print(f"The largest number from the {num} is {find_largest(num)}")
# Out:
# The largest number from the [3, 7, 1, 9, 4, 5] is 9

# %% [markdown]
# 👉 **Instructions:**
#
# 1. Define a function called find_largest(lst) that takes a list of integers lst as input and returns the largest integer in the list using recursion.
#
# 2. If the length of the list is 1, the largest integer is simply the first (and only) element of the list, so return lst[0].
#
# 3. If the length of the list is greater than 1, split the list into two parts: the first half and the second half.
#
# 4. Recursively call the find_largest function on each half of the list.
#
# 5. Compare the two results obtained from the recursive calls and return the larger one as the result.
#
# 6. Test the find_largest function with some example inputs to make sure it works as expected.

# %% [markdown]
# ## **Activity 4:**

# %% [markdown]
# ### **Balancing Paranthesis (())** 󠁻
#
# You are given a list of strings, where each string contains a set of parentheses. Write a Python function to determine if the parentheses in each string are balanced. A string is considered balanced if it contains the same number of opening and closing parentheses, and if the opening parentheses occur before the closing parentheses.
#
# For example, consider the following list of strings:
#
#
# ```
# lst = ['()()', '((()))', '(())(', '(()))']
#
# ```
#
# The first two strings are balanced, while the last two are not. The function should return a list of Boolean values indicating whether each string is balanced or not:
#
#
# ```
# [True, True, False, False]
#
# ```
# Write a Python function called are_parentheses_balanced(lst) that takes a list of strings lst as input and returns a list of Boolean values indicating whether each string is balanced or not.
#
#
# Additionally, find the time and space complexity of the code you have developed.

# %% [markdown]
# ![202203111_parathesese_1000x700.png](data:image/png;base64,...)

# %%
# Write your code here
# Write your code here
def are_parentheses_balanced(lst):
    result = []
    
    for string in lst:
        is_balanced = check_balanced(string)
        result.append(is_balanced)
    return result

def check_balanced(string):
    parenthese = []
    
    for char in string:
        if char == '(':
            parenthese.append(char)
            
        elif char == ')':
            
            if len(parenthese) == 0 or parenthese.pop() != '(':
                return False
            
    return len(parenthese) == 0

# %%
# Example usage
lst = ['()()', '((()))', '(())(', '(()))']
print(are_parentheses_balanced(lst)) # Output: [True, True, False, False]
# Out:
# [True, True, False, False]

# %% [markdown]
# 👉 **Instructions:**
#
# 1. Define a function called are_parentheses_balanced(lst) that takes a list of strings lst as input and returns a list of Boolean values indicating whether each string is balanced or not.
#
# 2. Inside the are_parentheses_balanced function, define an empty list called result to store the results.
#
# 3. For each string, call a recursive function called is_balanced to check whether the string is balanced.
#
# 4. Define the is_balanced function that takes three arguments: the string itself, a count of the number of opening parentheses seen so far, and a count of the number of closing parentheses seen so far.
#
# 5. If there are more closing parentheses than opening parentheses, the string is not balanced, so return False.
#
# 6. If the string is empty, the string is balanced if and only if the number of opening parentheses seen so far is equal to the number of closing parentheses seen so far, so return count_open == count_close.
#
# 7. If the first character in the string is an opening parenthesis, recursively call the is_balanced function with the remaining part of the string and increment the count of opening parentheses seen so far.
#
# 8. If the first character in the string is a closing parenthesis, recursively call the is_balanced function with the remaining part of the string and increment the count of closing parentheses seen so far.
#
# 9. If the first character in the string is neither an opening nor a closing parenthesis, simply ignore it and recursively call the is_balanced function with the remaining part of the string.
#
# 10. Repeat steps 8-12 until the string is empty.
